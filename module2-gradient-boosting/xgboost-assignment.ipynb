# %% [markdown]
# # Assignment
# - Continue to participate in the [Kaggle Caterpillar competition](https://www.kaggle.com/c/caterpillar-tube-pricing).
# - Do more feature engineering.
# - Use xgboost for gradient boosting.
# - Submit new predictions.
# - Commit your notebook to your fork of the GitHub repo.
#
# ## Stretch Goals
# - Improve your scores on Kaggle.
# - Make visualizations and share on Slack.
# - Look at [Kaggle Kernels](https://www.kaggle.com/c/caterpillar-tube-pricing/kernels) for ideas about feature engineering and visualization.
# - Read more about gradient boosting:
#   - [A Gentle Introduction to the Gradient Boosting Algorithm for Machine Learning](https://machinelearningmastery.com/gentle-introduction-gradient-boosting-algorithm-machine-learning/)
#   - [A Kaggle Master Explains Gradient Boosting](http://blog.kaggle.com/2017/01/23/a-kaggle-master-explains-gradient-boosting/)
#   - [_An Introduction to Statistical Learning_](http://www-bcf.usc.edu/~gareth/ISL/ISLR%20Seventh%20Printing.pdf) Chapter 8
#   - [Gradient Boosting Explained](http://arogozhnikov.github.io/2016/06/24/gradient_boosting_explained.html)

# %%
import pandas as pd
import numpy as np
from glob import glob
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
import category_encoders as ce
from sklearn.metrics import mean_squared_error
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
trainval = pd.read_csv('competition_data/train_set.csv')
test = pd.read_csv('competition_data/test_set.csv')

# %%
# Create dict of all dataframes
dfs = {}
for path in glob('competition_data/*.csv'):
    folder, file = path.split('/')
    name, extension = file.split('.')
    if name != 'train_set' and name != 'test_set':
        dfs[name] = pd.read_csv(path)

# %%
for df in dfs:
    display(dfs[df])
# dfs['comp_threaded']
# Out:
#     component_id component_type_id  adaptor_angle  overall_length  hex_size end_form_id_1 connection_type_id_1  length_1  thread_size_1  thread_pitch_1 nominal_size_1 end_form_id_2 connection_type_id_2  length_2  thread_size_2  thread_pitch_2  nominal_size_2 end_form_id_3 connection_type_id_3  length_3  thread_size_3  thread_pitch_3  nominal_size_3 end_form_id_4 connection_type_id_4  length_4  thread_size_4  thread_pitch_4  nominal_size_4 unique_feature orientation  weight
# 0         C-0007            CP-014            nan           24.40     12.70         A-001                B-001       nan           0.44           20.00            NaN         A-004                  NaN       nan            nan             nan            6.35           NaN                  NaN       nan            nan             nan             nan           NaN                  NaN       nan            nan             nan             nan             No          No    0.03
# 1         C-0030            CP-015          90.00             nan       nan         A-003                  NaN     47.00            nan             nan             42         A-003                  NaN     47.00            nan             nan           42.00           NaN                  NaN       nan            nan             nan             nan           NaN                  NaN       nan            nan             nan             nan             No         Yes    0.91
# 2         C-0041            CP-014            nan           28.00     32.00         A-004                  NaN       nan            nan             nan           21.7         A-001                B-002       nan           0.81           16.00             nan           NaN                  NaN       nan            nan             nan             nan           NaN                  NaN       nan            nan             nan             nan             No          No    0.12
# 3         C-0043            CP-014            nan           38.00     27.00         A-003                  NaN       nan            nan             nan           21.7         A-001                B-002       nan           0.81           16.00             nan           NaN                  NaN       nan            nan             nan             nan           NaN                  NaN       nan            nan             nan             nan             No          No    0.09
# 4         C-0044            CP-014            nan           30.50     41.28         A-004                  NaN       nan            nan             nan             34         A-001                B-002       nan           1.44           12.00             nan           NaN                  NaN       nan            nan             nan             nan           NaN                  NaN       nan            nan             nan             nan             No          No    0.18
# 5         C-0069            CP-015          90.00             nan       nan         A-001                B-002     29.00           0.81           16.00            NaN         A-004                  NaN     16.00            nan             nan           17.30           NaN                  NaN       nan            nan             nan             nan           NaN                  NaN       nan            nan             nan             nan            Yes         Yes    0.22
# 6         C-0070            CP-015          90.00             nan       nan         A-003                  NaN     30.00            nan             nan           21.7         A-001                B-002     27.00           0.81           16.00             nan           NaN                  NaN       nan            nan             nan             nan           NaN                  NaN       nan            nan             nan             nan             No         Yes    0
NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21141         TA-21143  SP-0004  SP-0006  SP-0058  SP-0069  SP-0080      NaN      NaN   NaN   NaN    NaN
# 21142         TA-21144  SP-0004  SP-0006  SP-0058  SP-0069  SP-0080      NaN      NaN   NaN   NaN    NaN
# 21143         TA-21145  SP-0063  SP-0069  SP-0080      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21144         TA-21146  SP-0063  SP-0069  SP-0080      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21145         TA-21147  SP-0004  SP-0058      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21146         TA-21148  SP-0058  SP-0080      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21147         TA-21149  SP-0063  SP-0080      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21148         TA-21150  SP-0007  SP-0024  SP-0070  SP-0080      NaN      NaN      NaN   NaN   NaN    NaN
# 21149         TA-21151  SP-0007  SP-0024  SP-0070  SP-0080      NaN      NaN      NaN   NaN   NaN    NaN
# 21150         TA-21152  SP-0058  SP-0080      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21151         TA-21153  SP-0058  SP-0080      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21152         TA-21154  SP-0058  SP-0080      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21153         TA-21155  SP-0058  SP-0080      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21154         TA-21156  SP-0058  SP-0080      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21155         TA-21157  SP-0004  SP-0024  SP-0069  SP-0080      NaN      NaN      NaN   NaN   NaN    NaN
# 21156         TA-21158  SP-0070  SP-0080      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21157         TA-21159  SP-0026  SP-0063  SP-0069  SP-0080      NaN      NaN      NaN   NaN   NaN    NaN
# 21158         TA-21160  SP-0007  SP-0063  SP-0068  SP-0080      NaN      NaN      NaN   NaN   NaN    NaN
# 21159         TA-21161  SP-0063  SP-0068  SP-0080      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21160         TA-21162  SP-0063  SP-0069  SP-0080      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21161         TA-21163  SP-0063  SP-0069  SP-0080      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21162         TA-21164  SP-0004  SP-0024  SP-0058  SP-0069  SP-0080      NaN      NaN   NaN   NaN    NaN
# 21163         TA-21165  SP-0004  SP-0024  SP-0069  SP-0080      NaN      NaN      NaN   NaN   NaN    NaN
# 21164         TA-21166  SP-0004  SP-0012  SP-0024  SP-0058  SP-0069  SP-0080      NaN   NaN   NaN    NaN
# 21165         TA-21167  SP-0004  SP-0012  SP-0058  SP-0069  SP-0080      NaN      NaN   NaN   NaN    NaN
# 21166         TA-21168  SP-0004  SP-0012  SP-0058  SP-0069  SP-0080      NaN      NaN   NaN   NaN    NaN
# 21167         TA-21169  SP-0004  SP-0024  SP-0058  SP-0070  SP-0080      NaN      NaN   NaN   NaN    NaN
# 21168         TA-21170  SP-0063  SP-0080      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21169         TA-21171  SP-0026  SP-0058  SP-0070  SP-0080      NaN      NaN      NaN   NaN   NaN    NaN
# 21170         TA-21172  SP-0026  SP-0058  SP-0070  SP-0080      NaN      NaN      NaN   NaN   NaN    NaN
# 21171         TA-21173  SP-0070  SP-0080      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21172         TA-21174  SP-0058  SP-0080      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21173         TA-21175  SP-0058  SP-0080      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21174         TA-21176  SP-0063  SP-0069  SP-0080      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21175         TA-21177  SP-0063  SP-0069  SP-0080      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21176         TA-21178      NaN      NaN      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21177         TA-21179  SP-0058  SP-0070  SP-0080      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21178         TA-21180  SP-0007  SP-0024  SP-0069  SP-0080      NaN      NaN      NaN   NaN   NaN    NaN
# 21179         TA-21181  SP-0007  SP-0024  SP-0069  SP-0080      NaN      NaN      NaN   NaN   NaN    NaN
# 21180         TA-21182  SP-0024  SP-0063  SP-0070  SP-0080      NaN      NaN      NaN   NaN   NaN    NaN
# 21181         TA-21183  SP-0024  SP-0063  SP-0070  SP-0080      NaN      NaN      NaN   NaN   NaN    NaN
# 21182         TA-21184  SP-0007  SP-0058  SP-0070  SP-0080      NaN      NaN      NaN   NaN   NaN    NaN
# 21183         TA-21185  SP-0004  SP-0024  SP-0069  SP-0080      NaN      NaN      NaN   NaN   NaN    NaN
# 21184         TA-21186  SP-0004  SP-0024  SP-0069  SP-0080      NaN      NaN      NaN   NaN   NaN    NaN
# 21185         TA-21187  SP-0004  SP-0024  SP-0069  SP-0080      NaN      NaN      NaN   NaN   NaN    NaN
# 21186         TA-21188  SP-0007  SP-0024  SP-0070  SP-0080  SP-0082      NaN      NaN   NaN   NaN    NaN
# 21187         TA-21189      NaN      NaN      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21188         TA-21190      NaN      NaN      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21189         TA-21191  SP-0007  SP-0024  SP-0063  SP-0069  SP-0080      NaN      NaN   NaN   NaN    NaN
# 21190         TA-21192      NaN      NaN      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21191         TA-21193      NaN      NaN      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21192         TA-21194      NaN      NaN      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21193         TA-21195      NaN      NaN      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21194         TA-21196  SP-0007  SP-0080      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21195         TA-21197  SP-0007  SP-0080      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21196         TA-21198  SP-0058  SP-0080      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
# 21197         TA-21199  SP-0058  SP-0080      NaN      NaN      NaN      NaN      NaN   NaN   NaN    NaN
#
# [21198 rows x 11 columns]
#    component_id component_type_id  hex_nut_size  seat_angle  length thread_size  thread_pitch  diameter blind_hole orientation  weight
# 0        C-1621            CP-025         20.64         nan   17.00        .687         16.00       nan        NaN          No    0.01
# 1        C-1624            CP-025         34.92         nan   26.50       1.187         12.00       nan        NaN          No    0.04
# 2        C-1623            CP-025         28.58         nan   23.50       1.000         14.00       nan        NaN          No    0.04
# 3        C-1622            CP-025         23.81         nan   20.00        .812         16.00       nan        NaN          No    0.04
# 4        C-1625            CP-025         41.28         nan   27.50       1.437         12.00       nan        NaN          No    0.13
# 5        C-1626            CP-025         47.63         nan   27.50       1.687         12.00       nan        NaN          No    0.15
# 6        C-1620            CP-025         17.46         nan   15.00        .562         18.00       nan        NaN          No    0.02
# 7        C-1867            CP-025         57.15         nan   27.50       2.000         12.00       nan        NaN          No    0.22
# 8        C-2029            CP-025         23.81         nan   20.00        .812         16.00       nan        NaN          No    0.03
# 9        C-0579            CP-025         24.00         nan   20.00        .812         16.00       nan        NaN          No    0.16
# 10       C-0580            CP-025         36.00         nan   26.50       1.187         12.00       nan        NaN          No    0.11
# 11       C-0134            CP-025         17.46         nan   15.00        .562         18.00       nan        NaN          No    0.02
# 12       C-0390            CP-025         23.81         nan   21.00        .812         16.00       nan        NaN          No    0.03
# 13       C-2027            CP-025         34.92         nan   26.50       1.187         12.00       nan        NaN          No    0.10
# 14       C-0337            CP-025         20.64         nan   16.00        .687         16.00       nan        NaN          No    0.02
# 15       C-2030            CP-025         20.64         nan   17.00        .687         16.00       nan        NaN          No    0.02
# 16       C-2025            CP-025         47.63         nan   27.50       1.687         12.00       nan        NaN          No    0.15
# 17       C-1760            CP-025         41.28         nan   27.79       1.437         12.00       nan        NaN          No    0.12
# 18       C-2028            CP-025         28.58         nan   24.00       1.000         14.00       nan        NaN          No    0.05
# 19       C-0102            CP-025         24.00         nan   20.00        .812         16.00       nan        NaN          No    0.03
# 20       C-1059            CP-025         28.58         nan   24.00       1.000         14.00       nan        NaN          No    0.05
# 21       C-0097            CP-025         22.00         nan   17.00        .687         16.00       nan        NaN          No    0.03
# 22       C-2026            CP-025         41.28         nan   27.50       1.437         12.00       nan        NaN          No    0.13
# 23       C-0095            CP-025         30.00         nan   23.50       1.000         14.00       nan        NaN          No    0.05
# 24       C-0261            CP-025         47.62         nan   27.80       1.687         12.00       nan        NaN          No    0.15
# 25       C-0004            CP-026         15.88       37.00   17.00        .500         20.00       nan        NaN          No    0.01
# 26       C-1202            CP-026         22.22       45.00   41.28        .750         16.00       nan        NaN          No    0.04
# 27       C-1442            CP-026         57.15       37.00   36.10       1.875         12.00       nan        NaN          No    0.34
# 28       C-1421            CP-026         25.40       37.00   24.90        .875         14.00       nan        NaN          No    0.05
# 29       C-0448            CP-026         22.23       37.00   21.60        .750         16.00       nan        NaN          No    0.03
# 30       C-0336            CP-026         25.40       37.00   24.60        .875         14.00       nan        NaN          No    0.04
# 31       C-0308            CP-026         25.40         nan   24.60        .875         14.00       nan        NaN          No    0.04
# 32       C-1952            CP-026         22.23       45.00   28.45        .750         16.00       nan        NaN          No    0.04
# 33       C-1845            CP-026         14.29       37.00   15.80        .437         20.00       nan        NaN          No    0.01
# 34       C-1577            CP-026         34.92       37.00   27.40       1.187         12.00       nan        NaN          No    0.09
# 35       C-1384            CP-026         31.75       37.00   25.90       1.062         12.00       nan        NaN          No    0.07
# 36       C-1200            CP-026         14.29       45.00   23.81        .437         20.00       nan        NaN          No    0.03
# 37       C-1199            CP-026         19.05         nan   52.40        .625         18.00       nan        NaN          No    0.02
# 38       C-0444            CP-026         38.10       37.00   28.70       1.312         12.00       nan        NaN          No    0.11
# 39       C-0831            CP-026         50.80       37.00   31.20       1.625         12.00       nan        NaN          No    0.26
# 40       C-1848            CP-026         31.75       37.00   26.20       1.062         12.00       nan        NaN          No    0.08
# 41       C-1243            CP-026         17.46       37.00   18.50        .562         18.00       nan        NaN          No    0.02
# 42       C-1927            CP-027           nan         nan   35.00         M10          1.50     20.00         No          No    0.07
# 43       C-1964            CP-027           nan         nan   20.00         M10          1.50     20.00         No          No    0.04
# 44       C-1969            CP-027           nan         nan   45.00         M10          1.50     20.00         No          No    0.09
# 45       C-1966            CP-027           nan         nan   40.00         M12          1.75     10.50         No          No    0.13
# 46       C-1963            CP-027           nan         nan   25.00         M10          1.50     20.00         No          No    0.05
# 47       C-1694            CP-027           nan         nan   40.00        .375         16.00     30.00         No          No    0.20
# 48       C-1318            CP-027           nan         nan   39.00         M10          1.50     20.00        Yes          No     nan
# 49       C-0720            CP-027           nan         nan   90.00         M12          1.75     25.00         No          No    0.22
# 50       C-0315            CP-027           nan         nan   40.00        .375         16.00     30.00         No          No    0.20
# 51       C-1316            CP-027           nan         nan   13.00        .375         16.00     19.00         No          No    0.02
# 52       C-0345            CP-027           nan         nan   23.00          M8          1.25     19.00         No          No    0.04
# 53       C-1980            CP-027           nan         nan   25.00         M10          1.50     25.00         No          No    0.08
# 54       C-1793            CP-027           nan         nan   30.00         M10          1.50     25.00         No          No    0.10
# 55       C-1580            CP-027           nan         nan   20.57        .375         16.00     15.88         No          No    0.02
# 56       C-0827            CP-027           nan         nan    1.00        .312         18.00      0.62         No          No    0.03
# 57       C-1968            CP-027           nan         nan   30.00         M10          1.50     20.00         No          No    0.06
# 58       C-1967            CP-027           nan         nan   25.00         M10          1.50     25.00         No          No    0.09
# 59       C-0321            CP-027           nan         nan   15.00          M8          1.25     16.00         No          No    0.02
# 60       C-1320            CP-027           nan         nan   15.00          M6          1.00     12.00         No          No    0.01
# 61       C-1965            CP-027           nan         nan   58.50         M10          1.50     20.00         No          No    0.11
# 62       C-0035            CP-027           nan         nan   12.00        .250         20.00     12.00         No          No    0.01
# 63       C-1530            CP-027           nan         nan   22.23        .500         13.00     25.40         No          No    0.07
# 64       C-1962            CP-027           nan         nan   21.00         M10          1.50     25.00         No          No    0.07

# %%
dfs['test_set']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-eec37adf9974> in <module>
# ----> 1 dfs['test_set']
#
# KeyError: 'test_set'

# %%
def return_shared_columns(df1, df2):
    shared_column = set(df1.columns) & set(df2.columns)
    if shared_column:
        return shared_column
    else:
        return None
shared_columns= {}
for df in dfs:
    shared_columns[df] = {}
    for df2 in dfs:
        if df != df2:
            shared_column = return_shared_columns(dfs[df], dfs[df2])
            if shared_column:
                shared_columns[df][df2] = shared_column

# %%
shared_columns['comp_threaded']
# Out:
# {'comp_adaptor': {'adaptor_angle',
#   'component_id',
#   'component_type_id',
#   'connection_type_id_1',
#   'connection_type_id_2',
#   'end_form_id_1',
#   'end_form_id_2',
#   'hex_size',
#   'length_1',
#   'length_2',
#   'nominal_size_1',
#   'nominal_size_2',
#   'orientation',
#   'overall_length',
#   'thread_pitch_1',
#   'thread_pitch_2',
#   'thread_size_1',
#   'thread_size_2',
#   'unique_feature',
#   'weight'},
#  'comp_straight': {'component_id',
#   'component_type_id',
#   'orientation',
#   'overall_length',
#   'unique_feature',
#   'weight'},
#  'comp_tee': {'component_id',
#   'component_type_id',
#   'orientation',
#   'overall_length',
#   'unique_feature',
#   'weight'},
#  'comp_boss': {'component_id',
#   'component_type_id',
#   'orientation',
#   'unique_feature',
#   'weight'},
#  'components': {'component_id', 'component_type_id'},
#  'comp_float': {'component_id', 'component_type_id', 'orientation', 'weight'},
#  'comp_elbow': {'component_id',
#   'component_type_id',
#   'orientation',
#   'overall_length',
#   'unique_feature',
#   'weight'},
#  'comp_sleeve': {'component_id',
#   'component_type_id',
#   'orientation',
#   'unique_feature',
#   'weight'},
#  'comp_hfl': {'component_id', 'component_type_id', 'orientation', 'weight'},
#  'comp_other': {'component_id', 'weight'},
#  'type_component': {'component_type_id'},
#  'comp_nut': {'component_id', 'component_type_id', 'orientation', 'weight'}}

# %%
type(shared_columns)
# Out:
# dict

# %%
for d1 in shared_columns:
    print(d1 + '\n')
    for d2 in shared_columns[df]:
        print(d2 + '\n')
        print(shared_columns[df][d2])
# Out:
# comp_threaded
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}
# comp_adaptor
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}
# tube_end_form
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}
# comp_straight
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}
# comp_tee
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}
# comp_boss
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}
# components
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}
# comp_float
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}
# bill_of_materials
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}
# comp_elbow
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}
# type_connection
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}
# comp_sleeve
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}
# tube
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}
# comp_hfl
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}
# type_end_form
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}
# comp_other
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}
# type_component
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}
# specs
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}
# comp_nut
#
# comp_threaded
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_adaptor
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_straight
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_tee
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_boss
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# components
#
# {'component_id', 'component_type_id'}
# comp_float
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_elbow
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_sleeve
#
# {'component_id', 'component_type_id', 'weight', 'orientation', 'length'}
# tube
#
# {'length', 'diameter'}
# comp_hfl
#
# {'weight', 'component_id', 'orientation', 'component_type_id'}
# comp_other
#
# {'weight', 'component_id'}
# type_component
#
# {'component_type_id'}

# %%
train_shared = {}
for df in dfs:
    shared_column = return_shared_columns(trainval, dfs[df])
    if shared_column:
        train_shared[df] = shared_column

# %%
for df in train_shared:
    temp_df = dfs[df]
    categoricals = temp_df.select_dtypes(exclude='number').columns.tolist()
    for col in categoricals:
        temp_df[col] = temp_df[col].fillna('MISSING')
    trainval = trainval.merge(temp_df, how='left')

# %%
for df in train_shared:
    temp_df = dfs[df]
    categoricals = temp_df.select_dtypes(exclude='number').columns.tolist()
    for col in categoricals:
        temp_df[col] = temp_df[col].fillna('MISSING')
    test = test.merge(temp_df, how='left')

# %%
trainval.columns.tolist()
# Out:
# ['tube_assembly_id',
#  'supplier',
#  'quote_date',
#  'annual_usage',
#  'min_order_quantity',
#  'bracket_pricing',
#  'quantity',
#  'cost',
#  'component_id_1',
#  'quantity_1',
#  'component_id_2',
#  'quantity_2',
#  'component_id_3',
#  'quantity_3',
#  'component_id_4',
#  'quantity_4',
#  'component_id_5',
#  'quantity_5',
#  'component_id_6',
#  'quantity_6',
#  'component_id_7',
#  'quantity_7',
#  'component_id_8',
#  'quantity_8',
#  'material_id',
#  'diameter',
#  'wall',
#  'length',
#  'num_bends',
#  'bend_radius',
#  'end_a_1x',
#  'end_a_2x',
#  'end_x_1x',
#  'end_x_2x',
#  'end_a',
#  'end_x',
#  'num_boss',
#  'num_bracket',
#  'other',
#  'spec1',
#  'spec2',
#  'spec3',
#  'spec4',
#  'spec5',
#  'spec6',
#  'spec7',
#  'spec8',
#  'spec9',
#  'spec10']

# %%
shared_list = []
train_list = []
for i in train_shared:
    train_list.append(i)
for i in shared_columns:
    shared_list.append(i)
train_list
# Out:
# ['bill_of_materials', 'tube', 'specs']

# %%
remaining_difference = set(shared_list).difference(train_list)

# %%
remaining_difference
# Out:
# {'comp_adaptor',
#  'comp_boss',
#  'comp_elbow',
#  'comp_float',
#  'comp_hfl',
#  'comp_nut',
#  'comp_other',
#  'comp_sleeve',
#  'comp_straight',
#  'comp_tee',
#  'comp_threaded',
#  'components',
#  'tube_end_form',
#  'type_component',
#  'type_connection',
#  'type_end_form'}

# %%
for df in remaining_difference:
    if df != 'components':
        temp_df = dfs[df]
        display(temp_df)
        categoricals = temp_df.select_dtypes(exclude='number').columns.tolist()
        for col in categoricals:
            temp_df[col] = temp_df[col].fillna('MISSING')
        print(df)
        trainval = trainval.merge(temp_df, how='left', on='component_id_1')
# Out:
#    component_id component_type_id  adaptor_angle  overall_length end_form_id_1 connection_type_id_1  length_1  thread_size_1  thread_pitch_1  nominal_size_1 end_form_id_2 connection_type_id_2  length_2  thread_size_2  thread_pitch_2  nominal_size_2  hex_size unique_feature orientation  weight
# 0        C-0005            CP-028            nan           58.40         A-001                B-001       nan           1.31           12.00             nan         A-001                B-004       nan           1.00           11.50             nan     34.93             No          No    0.21
# 1        C-0006            CP-028            nan           34.80         A-001                B-001       nan           0.44           20.00             nan         A-001                B-005       nan           0.75           16.00             nan     22.20             No          No    0.08
# 21       C-1695            CP-028            nan           30.00         A-001                B-006       nan           0.75           16.00             nan         A-007                 9999       nan        9999.00         9999.00             nan     25.40             No          No     nan
# 22       C-1812            CP-028            nan           35.10         A-007                B-004       nan           0.38           18.00             nan         A-007                B-004       nan           0.38           18.00             nan       nan             No          No    0.09
# 23       C-1828            CP-028            nan           28.40         A-001                B-005       nan           1.31           12.00             nan         A-007                B-005       nan           0.56           18.00             nan     38.10             No          No    0.18
# 24       C-1868            CP-029          90.00             nan         A-001                B-005     65.50           0.75           16.00             nan         A-001                B-002     28.00           0.81           16.00             nan       nan             No         Yes    0.23
# comp_adaptor
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-74-9f1b72fcb4bb> in <module>
#       7             temp_df[col] = temp_df[col].fillna('MISSING')
#       8         print(df)
# ----> 9         trainval = trainval.merge(temp_df, how='left')
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6866                      right_on=right_on, left_index=left_index,
#    6867                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6868                      copy=copy, indicator=indicator, validate=validate)
#    6869
#    6870     def round(self, decimals=0, *args, **kwargs):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     522             warnings.warn(msg, UserWarning)
#     523
# --> 524         self._validate_specification()
#     525
#     526         # note this function has side effects
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _validate_specification(self)
#    1031                         'left_index={lidx}, right_index={ridx}'
#    1032                         .format(lon=self.left_on, ron=self.right_on,
# -> 1033                                 lidx=self.left_index, ridx=self.right_index))
#    1034                 if not common_cols.is_unique:
#    1035                     raise MergeError("Data columns not unique: {common!r}"
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
trainval.columns
# Out:
# Index(['tube_assembly_id', 'supplier', 'quote_date', 'annual_usage', 'min_order_quantity', 'bracket_pricing', 'quantity', 'cost', 'component_id_1', 'quantity_1', 'component_id_2', 'quantity_2', 'component_id_3', 'quantity_3', 'component_id_4', 'quantity_4', 'component_id_5', 'quantity_5', 'component_id_6', 'quantity_6', 'component_id_7', 'quantity_7', 'component_id_8', 'quantity_8', 'material_id', 'diameter', 'wall', 'length', 'num_bends', 'bend_radius', 'end_a_1x', 'end_a_2x', 'end_x_1x', 'end_x_2x', 'end_a', 'end_x', 'num_boss', 'num_bracket', 'other', 'spec1', 'spec2', 'spec3', 'spec4', 'spec5', 'spec6', 'spec7', 'spec8', 'spec9', 'spec10'], dtype='object')

# %%
test.columns
# Out:
# Index(['id', 'tube_assembly_id', 'supplier', 'quote_date', 'annual_usage', 'min_order_quantity', 'bracket_pricing', 'quantity', 'component_id_1', 'quantity_1', 'component_id_2', 'quantity_2', 'component_id_3', 'quantity_3', 'component_id_4', 'quantity_4', 'component_id_5', 'quantity_5', 'component_id_6', 'quantity_6', 'component_id_7', 'quantity_7', 'component_id_8', 'quantity_8', 'material_id', 'diameter', 'wall', 'length', 'num_bends', 'bend_radius', 'end_a_1x', 'end_a_2x', 'end_x_1x', 'end_x_2x', 'end_a', 'end_x', 'num_boss', 'num_bracket', 'other', 'spec1', 'spec2', 'spec3', 'spec4', 'spec5', 'spec6', 'spec7', 'spec8', 'spec9', 'spec10'], dtype='object')

# %%
trainval_tube_assemblies = trainval['tube_assembly_id'].unique()
test_tube_assemblies = test['tube_assembly_id'].unique()
len(trainval_tube_assemblies), len(test_tube_assemblies)
# Out:
# (8855, 8856)

# %%
train_tube_assemblies, val_tube_assemblies = train_test_split(
    trainval_tube_assemblies
)

# %%
train = trainval[trainval.tube_assembly_id.isin(train_tube_assemblies)].drop(columns='tube_assembly_id')
val = trainval[trainval.tube_assembly_id.isin(val_tube_assemblies)].drop(columns='tube_assembly_id')
train.shape, val.shape, trainval.shape
# Out:
# ((22822, 48), (7391, 48), (30213, 49))

# %%
train.isnull().sum()
# Out:
# supplier                  0
# quote_date                0
# annual_usage              0
# min_order_quantity        0
# bracket_pricing           0
# quantity                  0
# cost                      0
# component_id_1            0
# quantity_1             1044
# component_id_2            0
# quantity_2             6732
# component_id_3            0
# quantity_3            17514
# component_id_4            0
# quantity_4            22308
# component_id_5            0
# quantity_5            22777
# component_id_6            0
# quantity_6            22801
# component_id_7            0
# quantity_7            22814
# component_id_8            0
# quantity_8            22819
# material_id               0
# diameter                  0
# wall                      0
# length                    0
# num_bends                 0
# bend_radius               0
# end_a_1x                  0
# end_a_2x                  0
# end_x_1x                  0
# end_x_2x                  0
# end_a                     0
# end_x                     0
# num_boss                  0
# num_bracket               0
# other                     0
# spec1                     0
# spec2                     0
# spec3                     0
# spec4                     0
# spec5                     0
# spec6                     0
# spec7                     0
# spec8                     0
# spec9                     0
# spec10                    0
# dtype: int64

# %%
from xgboost import XGBRegressor

target = 'cost'
y_train_log = np.log1p(train[target])
y_val_log = np.log1p(val[target])
X_train = train.drop(columns=[target])
X_val = val.drop(columns=[target])

encoder = ce.OrdinalEncoder()
X_train_encoded = encoder.fit_transform(X_train)
X_val_encoded = encoder.transform(X_val)

eval_set = [(X_train_encoded, y_train_log),
            (X_val_encoded, y_val_log)]

model = XGBRegressor(n_estimators=1000, n_jobs=-1)

# class XGBRegressorEval(XGBRegressor):
#     def fit(self, *args, **kwargs):
#         return super().fit(*args, eval_set=eval_set, eval_metrics='rmse',
#                            early_stopping_rounds=10, **kwargs)
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))
# pipeline = make_pipeline(ce.OrdinalEncoder(),
#                          XGBRegressor(n_estimators=1000, n_jobs=-1)
#                         )

# %%
model.fit(X_train_encoded, y_train_log, eval_set=eval_set, eval_metric='rmse',
          early_stopping_rounds=12)

# %%
pipeline.fit(X_train, y_train_log)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-2a0567c3c2f2> in <module>
# ----> 1 pipeline.fit(X_train, y_train_log)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     265         Xt, fit_params = self._fit(X, y, **fit_params)
#     266         if self._final_estimator is not None:
# --> 267             self._final_estimator.fit(Xt, y, **fit_params)
#     268         return self
#     269
#
# <ipython-input-90-24a95967929a> in fit(self, *args, **kwargs)
#       3 class XGBRegressorEval(XGBRegressor):
#       4     def fit(self, *args, **kwargs):
# ----> 5         return super().fit(*args, eval_set=eval_set, eval_metrics='rmse',
#       6                            early_stopping_rounds=10, **kwargs)
#       7 def rmse(y_true, y_pred):
#
# NameError: name 'eval_set' is not defined
