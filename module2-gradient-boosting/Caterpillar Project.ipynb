# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.metrics import mean_squared_error, mean_squared_log_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import make_pipeline
import category_encoders as ce
from sklearn.model_selection import train_test_split
from zipfile import ZipFile
from glob import glob
from xgboost import XGBRegressor

# %%
#read zip files, print directories, extract all files
with ZipFile('data.zip', 'r') as zip:
    zip.printdir()
    zip.extractall()
# Out:
# File Name                                             Modified             Size
# competition_data/                              2015-06-29 21:06:12            0
# competition_data/bill_of_materials.csv         2015-06-24 16:21:48      1326876
# competition_data/comp_adaptor.csv              2015-06-24 16:21:48         2544
# competition_data/comp_boss.csv                 2015-06-24 16:21:48        10695
# competition_data/comp_elbow.csv                2015-06-24 16:21:48        12830
# competition_data/comp_float.csv                2015-06-24 16:21:48          703
# competition_data/comp_hfl.csv                  2015-06-24 16:21:48          438
# competition_data/comp_nut.csv                  2015-06-24 16:21:48         3324
# competition_data/comp_other.csv                2015-06-29 21:05:42        20941
# competition_data/comp_sleeve.csv               2015-06-24 16:21:48         2565
# competition_data/comp_straight.csv             2015-06-24 16:21:48        19721
# competition_data/comp_tee.csv                  2015-06-24 16:21:48          483
# competition_data/comp_threaded.csv             2015-06-24 16:21:48        24830
# competition_data/components.csv                2015-06-29 21:02:06        46891
# competition_data/specs.csv                     2015-06-24 16:21:48       974905
# competition_data/test_set.csv                  2015-06-24 16:21:48      1316313
# competition_data/train_set.csv                 2015-06-24 16:21:48      1655249
# competition_data/tube.csv                      2015-06-24 16:21:48      1386679
# competition_data/tube_end_form.csv             2015-06-29 09:12:18          302
# competition_data/type_component.csv            2015-06-24 16:21:48          743
# competition_data/type_connection.csv           2015-06-24 16:21:48          331
# competition_data/type_end_form.csv             2015-06-24 16:21:48          160

# %%
sample_sub= open('sample_submission.csv', 'r')

# %%
sample_sub= pd.read_csv(sample_sub)

# %%
#setting display option so i can see all columns
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
#Loaded train, test, tube, and bill data into pandas dataframes
test_data= pd.read_csv('competition_data/test_set.csv')
train_data= pd.read_csv('competition_data/train_set.csv')
tube_data= pd.read_csv('competition_data/tube.csv')
bill_data= pd.read_csv('competition_data/bill_of_materials.csv')
type_comp_data= pd.read_csv('competition_data/type_component.csv')
type_connect_data= pd.read_csv('competition_data/type_connection.csv')
type_end_form= pd.read_csv('competition_data/type_end_form.csv')

# %%
type_comp_data
# Out:
#    component_type_id                                 name
# 0             CP-001                  4-bolt Tig Straight
# 1             CP-002                   4-bolt MJ Straight
# 2             CP-003           4-bolt Braze/Weld Straight
# 3             CP-004           2-bolt Braze/Weld Straight
# 4             CP-005                   2-bolt MJ Straight
# 5             CP-006               Braze/Weld Flange Head
# 6             CP-007                       MJ Flange Head
# 7             CP-008              4-bolt Braze/Weld Elbow
# 8             CP-009                     4-bolt Tig Elbow
# 9             CP-010              2-bolt Braze/Weld Elbow
# 10            CP-011                      4-bolt MJ Elbow
# 11            CP-012                              MJ Plug
# 12            CP-013                        4-bolt MJ Tee
# 13            CP-014                    Threaded Straight
# 14            CP-015                       Threaded Elbow
# 15            CP-016                         Threaded Tee
# 16            CP-017               Threaded Lateral Cross
# 17            CP-018                        Threaded Boss
# 18            CP-019                          4-bolt Boss
# 19            CP-020                          2-bolt Boss
# 20            CP-021          Free-Floating 4-bolt Spacer
# 21            CP-022  Free-Floating 4-bolt Captive Flange
# 22            CP-023                     Stems and Shells
# 23            CP-024                              Sleeves
# 24            CP-025                             ORFS Nut
# 25            CP-026                      JIC 37 - 45 Nut
# 26            CP-027                          Weld On Nut
# 27            CP-028                     Straight Adapter
# 28            CP-029                        Elbow Adapter

# %%
type_end_form.head()
# Out:
#   end_form_id               name
# 0       A-001        Male (Stud)
# 1       A-002      Male (Swivel)
# 2       A-003    Braze-Weld Boss
# 3       A-004  Braze-Weld Socket
# 4       A-005         Swivel Nut

# %%
type_connect_data.head()
# Out:
#   connection_type_id                   name
# 0              B-001  37 deg Flare-SAE J514
# 1              B-002         ORFS-SAE J1453
# 2              B-003                Hi-Duty
# 3              B-004     NPTF-SAE J476/J514
# 4              B-005     SAE STOR-SAE J1926

# %%
# Out:
# 29

# %%
#load in all components data into pandas dataframes
components= pd.read_csv('competition_data\components.csv')
adaptors= pd.read_csv('competition_data\comp_adaptor.csv')
boss= pd.read_csv('competition_data\comp_boss.csv')
elbow= pd.read_csv('competition_data\comp_elbow.csv')
comp_float= pd.read_csv('competition_data\comp_float.csv')
hfl= pd.read_csv('competition_data\comp_hfl.csv')
nut= pd.read_csv('competition_data\comp_nut.csv')
other= pd.read_csv('competition_data\comp_other.csv')
sleeve= pd.read_csv('competition_data\comp_sleeve.csv')
straight= pd.read_csv('competition_data\comp_straight.csv')
tee= pd.read_csv('competition_data\comp_tee.csv')
threaded= pd.read_csv('competition_data\comp_threaded.csv')

# %%
components_with_type= pd.merge(components, type_comp_data, how='inner', on='component_type_id')

# %%
components_with_type
# Out:
#      component_id            name_x component_type_id  \
# 0          C-0001            SLEEVE            CP-024
# 1          C-0002            SLEEVE            CP-024
# 2          C-0003     SLEEVE-FLARED            CP-024
# 3          C-0048      SLEEVE-BRAZE            CP-024
# 4          C-0049       SLEEVE-ORFS            CP-024
# 5          C-0050       SLEEVE-ORFS            CP-024
# 6          C-0051       SLEEVE-ORFS            CP-024
# 7          C-0052       SLEEVE-ORFS            CP-024
# 8          C-0053       SLEEVE-ORFS            CP-024
# 9          C-0058      SLEEVE-90DEG            CP-024
# 10         C-0059      SLEEVE-90DEG            CP-024
# 11         C-0060      SLEEVE-90DEG            CP-024
# 12         C-0096            SLEEVE            CP-024
# 13         C-0101            SLEEVE            CP-024
# 14         C-0186       SLEEVE-ORFS            CP-024
# 15         C-0226     SLEEVE-FLARED            CP-024
# 16         C-0228            SLEEVE            CP-024
# 17         C-0309     SLEEVE-FLARED            CP-024
# 18         C-0391     SLEEVE-90 DEG            CP-024
# 19         C-0445       SLEEVE-ORFS            CP-024
# 20         C-0449     SLEEVE-FLARED            CP-024
# 21         C-0830    SLEEVE-FITTING            CP-024
# 22         C-1035    SLEEVE-REDUCER            CP-024
# 23         C-1074  CONNECTOR-BRAZED            CP-024
# 24         C-1244            SLEEVE            CP-024
# 25         C-1332       SLEEVE-ORFS            CP-024
# 26         C-1420    SLEEVE-FITTING            CP-024
# 27         C-1443     SLEEVE-FLARED            CP-024
# 28         C-1627       SLEEVE-ORFS            CP-024
# 29         C-1628       SLEEVE-ORFS            CP-024
# 30         C-1629       SLEEVE-ORFS            CP-024
# 31         C-1630       SLEEVE-ORFS            CP-024
# 32         C-1631       SLEEVE-ORFS            CP-024
# 33         C-1632       SLEEVE-ORFS            CP-024
# 34         C-1633       SLEEVE-ORFS            CP-024
# 35         C-1635  SLEEVE-FACE SEAL            CP-024
# 36         C-1652    SLEEVE-REDUCER            CP-024
# 37         C-1653    SLEEVE-REDUCER            CP-024
# 38         C-1654    SLEEVE-REDUCER            CP-024
# 39         C-1655    SLEEVE-REDUCER            CP-024
# 40         C-1656    SLEEVE-REDUCER            CP-024
# 41         C-1657    SLEEVE-REDUCER            CP-024
# 42         C-1658    SLEEVE-REDUCER            CP-024
# 43         C-1659    SLEEVE-REDUCER            CP-024
# 44         C-1660   SLEEEVE-REDUCER            CP-024
# 45         C-1661    SLEEVE-REDUCER            CP-024
# 46         C-1703       SLEEVE-ORFS            CP-024
# 47         C-1846     SLEEVE-FLARED            CP-024
# 48         C-1866       SLEEVE-ORFS            CP-024
# 49         C-2035    SLEEVE-ORIFICE            CP-024
# 50         C-0004               NUT            CP-026
# 51         C-0308        NUT-FLARED            CP-026
# 52         C-0336  NUT-37 DEG FLARE            CP-026
# 53         C-0444        NUT-FLARED            CP-026
# 54         C-0448        NUT-FLARED            CP-026
# 55         C-0831               NUT            CP-026
# 56         C-1199      FITTING-TUBE            CP-026
# 57         C-1200      NUT-45 (DEG)            CP-026
# 58         C-1202      NUT-45 (DEG)            CP-026
# 59         C-1243               NUT            CP-026
# 60         C-1384        NUT-FLARED            CP-026
# 61         C-1421       NUT-FITTING            CP-026
# 62         C-1442        NUT-FLARED            CP-026
# 63         C-1577        NUT-FLARED            CP-026
# 64         C-1845               NUT            CP-026
# 65         C-1848        NUT-FLARED            CP-026
# 66         C-1952    FITTING-FLARED            CP-026
# 67         C-0005       ADAPTER-STR            CP-028
# 68         C-0006       ADAPTER-STR            CP-028
# 69         C-0354  BUSHING-REDUCING            CP-028
# 70         C-0361   CONNECTOR-O-RIN            CP-028
# 71         C-0428         CONNECTOR            CP-028
# 72         C-0443        NUT-FLARED            CP-028
# 73         C-0823    NUT-INV FLARED            CP-028
# 74         C-1194     COUPLING-PIPE            CP-028
# 75         C-1195     COUPLING-PIPE            CP-028
# 76         C-1196     COUPLING-PIPE            CP-028
# 77         C-1197     COUPLING-PIPE            CP-028
# 78         C-1198     COUPLING-PIPE            CP-028
# 79         C-1229        NUT-FLARED            CP-028
# 80         C-1230        NUT-FLARED            CP-028
# 81         C-1312        NUT-FLARED            CP-028
# 82         C-1313    NUT-INV FLARED            CP-028
# 83         C-1435        NUT-FLARED            CP-028
# 84         C-1546      ADAPTER-PIPE            CP-028
# 85         C-1583       ADAPTER-STR            CP-028
# 86         C-1634       ADAPTER-STR            CP-028
# 87         C-1695           ADAPTER            CP-028
# 88         C-1812              BOSS            CP-028
# 89         C-1828       PLUG-O-RING            CP-028
# 90         C-1975        NUT-FLARED            CP-028
# 91         C-0007   CONNECTOR-FLARE            CP-014
# 92         C-0041    CONNECTOR-ORFS            CP-014
# 93         C-0043    CONNECTOR-ORFS            CP-014
# 94         C-0044    CONNECTOR-ORFS            CP-014
# 95         C-0074    CONNECTOR-STOR            CP-014
# 96         C-0077    CONNECTOR-ORFS            CP-014
# 97         C-0078       COUPLING AS            CP-014
# 98         C-0133         CONNECTOR            CP-014
# 99         C-0173         CONNECTOR            CP-014
# 100        C-0178           ADAPTER            CP-014
# 101        C-0179       UNION-BRAZE            CP-014
# 102        C-0180       UNION-BRAZE            CP-014
# 103        C-0181       UNION-BRAZE            CP-014
# 104        C-0182       UNION-BRAZE            CP-014
# 105        C-0216         CONNECTOR            CP-014
# 106        C-0217         CONNECTOR            CP-014
# 107        C-0218         CONNECTOR            CP-014
# 108        C-0240       UNION-BRAZE            CP-014
# 109        C-0253    CONNECTOR-ORFS            CP-014
# 110        C-0272       UNION-BRAZE            CP-014
# 111        C-0318         CONNECTOR            CP-014
# 112        C-0363         CONNECTOR            CP-014
# 113        C-0386  HEAD-O-RING SEAL            CP-014
# 114        C-0388     CONNECTOR-BHD            CP-014
# 115        C-0389     CONNECTOR-BHD            CP-014
# 116        C-0409  CONNECTOR-SWIVEL            CP-014
# 117        C-0410  CONNECTOR-SWIVEL            CP-014
# 118        C-0413         CONNECTOR            CP-014
# 119        C-0414         CONNECTOR            CP-014
# 120        C-0415         CONNECTOR            CP-014
# 121        C-0417       COUPLING AS            CP-014
# 122        C-0418         CONNECTOR            CP-014
# 123        C-0419       COUPLING AS            CP-014
# 124        C-0420         CONNECTOR            CP-014
# 125        C-0503         CONNECTOR            CP-014
# 126        C-0518         CONNECTOR            CP-014
# 127        C-0545       COUPLING AS            CP-014
# 128        C-0550    CONNECTOR-SEAL            CP-014
# 129        C-0596         CONNECTOR            CP-014
# 130        C-0638         CONNECTOR            CP-014
# 131        C-0651           FITTING            CP-014
# 132        C-0683    CONNECTOR-ORFS            CP-014
# 133        C-0702   CONNECTOR-BULKH            CP-014
# 134        C-0740         CONNECTOR            CP-014
# 135        C-0775         CONNECTOR            CP-014
# 136        C-0832  CONNECTOR-FLARED            CP-014
# 137        C-0833   CONNECTOR-FLARE            CP-014
# 138        C-0900   CONNECTOR-BRAZE            CP-014
# 139        C-0911         CONNECTOR            CP-014
# 140        C-0938           ADAPTER            CP-014
# 141        C-0945           ADAPTER            CP-014
# 142        C-0947           ADAPTER            CP-014
# 143        C-0948           ADAPTER            CP-014
# 144        C-0949           ADAPTER            CP-014
# 145        C-1067         CONNECTOR            CP-014
# 146        C-1078       ADAPTER-STR            CP-014
# 147        C-1218         CONNECTOR            CP-014
# 148        C-1338    CONNECTOR-WELD            CP-014
# 149        C-1393           FITTING            CP-014
# 150        C-1423         CONNECTOR            CP-014
# 151        C-1441    ADAPTER-O-RING            CP-014
# 152        C-1468       FITTING-A/C            CP-014
# 153        C-1469           NUT-A/C            CP-014
# 154        C-1470           NUT-A/C            CP-014
# 155        C-1475           NUT-A/C            CP-014
# 156        C-1479         CONNECTOR            CP-014
# 157        C-1486           NUT-A/C            CP-014
# 158        C-1547         CONNECTOR            CP-014
# 159        C-1578         CONNECTOR            CP-014
# 160        C-1637    CONNECTOR-SEAL            CP-014
# 161        C-1638    CONNECTOR-SEAL            CP-014
# 162        C-1639    CONNECTOR-SEAL            CP-014
# 163        C-1640    CONNECTOR-SEAL            CP-014
# 164        C-1641    CONNECTOR-SEAL            CP-014
# 165        C-1642    CONNECTOR-SEAL            CP-014
# 166        C-1643    CONNECTOR-ORFS            CP-014
# 167        C-1644    CONNECTOR-SEAL            CP-014
# 168        C-1645    CONNECTOR-SEAL            CP-014
# 169        C-1646    CONNECTOR-SEAL            CP-014
# 170        C-1647    CONNECTOR-SEAL            CP-014
# 171        C-1648    CONNECTOR-SEAL            CP-014
# 172        C-1649    CONNECTOR-SEAL            CP-014
# 173        C-1650    CONNECTOR-SEAL            CP-014
# 174        C-1701       COUPLING AS            CP-014
# 175        C-1704       COUPLING AS            CP-014
# 176        C-1710     CONNECTOR-SPL            CP-014
# 177        C-1714   CONNECTOR-FLARE            CP-014
# 178        C-1715   CONNECTOR-FLARE            CP-014
# 179        C-1716     CONNECTOR-SPL            CP-014
# 180        C-1718         CONNECTOR            CP-014
# 181        C-1722           FITTING            CP-014
# 182        C-1723           FITTING            CP-014
# 183        C-1724     CONNECTOR-SPL            CP-014
# 184        C-1728         CONNECTOR            CP-014
# 185        C-1743           FITTING            CP-014
# 186        C-1758         CONNECTOR            CP-014
# 187        C-1761     CONNECTOR-BHD            CP-014
# 188        C-1767    CONNECTOR-WELD            CP-014
# 189        C-1776       COUPLING AS            CP-014
# 190        C-1777         CONNECTOR            CP-014
# 191        C-1779       COUPLING AS            CP-014
# 192        C-1781    CONNECTOR-WELD            CP-014
# 193        C-1789         CONNECTOR            CP-014
# 194        C-1802         CONNECTOR            CP-014
# 195        C-1841         CONNECTOR            CP-014
# 196        C-1864   CONNECTOR-FLARE            CP-014
# 197        C-1869     CONNECTOR-SPL            CP-014
# 198        C-1870    CONNECTOR-ORFS            CP-014
# 199        C-1873    ADAPTER-O RING            CP-014
# 200        C-1879   CONNECTOR-O-RIN            CP-014
# 201        C-1885    CONNECTOR-ORFS            CP-014
# 202        C-1889    CONNECTOR-WELD            CP-014
# 203        C-1902    CONNECTOR-ORFS            CP-014
# 204        C-1903         CONNECTOR            CP-014
# 205        C-1907         CONNECTOR            CP-014
# 206        C-1908    CONNECTOR-ORFS            CP-014
# 207        C-1909         CONNECTOR            CP-014
# 208        C-1910    CONNECTOR-ORFS            CP-014
# 209        C-1913         CONNECTOR            CP-014
# 210        C-1936             BLOCK            CP-014
# 211        C-1976   CONNECTOR-FLARE            CP-014
# 212        C-0008              BOSS            CP-018
# 213        C-0009              BOSS            CP-018
# 214        C-0020              BOSS            CP-018
# 215        C-0054              BOSS            CP-018
# 216        C-0071              BOSS            CP-018
# 217        C-0082         BOSS-ORFS            CP-018
# 218        C-0111              BOSS            CP-018
# 219        C-0117              BOSS            CP-018
# 220        C-0151              BOSS            CP-018
# 221        C-0165      BOSS-FITTING            CP-018
# 222        C-0177              BOSS            CP-018
# 223        C-0199      COUPLET-WELD            CP-018
# 224        C-0208    CONNECTOR-WELD            CP-018
# 225        C-0209    CONNECTOR-WELD            CP-018
# 226        C-0213    CONNECTOR-WELD            CP-018
# 227        C-0214    CONNECTOR-WELD            CP-018
# 228        C-0215    CONNECTOR-WELD            CP-018
# 229        C-0242              BOSS            CP-018
# 230        C-0245      COUPLET-WELD            CP-018
# 231        C-0255              BOSS            CP-018
# 232        C-0258              BOSS            CP-018
# 233        C-0260              BOSS            CP-018
# 234        C-0262              BOSS            CP-018
# 235        C-0274              BOSS            CP-018
# 236        C-0278    CONNECTOR-WELD            CP-018
# 237        C-0348    CONNECTOR-WELD            CP-018
# 238        C-0356              BOSS            CP-018
# 239        C-0358              BOSS            CP-018
# 240        C-0393              BOSS            CP-018
# 241        C-0405              BOSS            CP-018
# 242        C-0411    CONNECTOR-WELD            CP-018
# 243        C-0425              BOSS            CP-018
# 244        C-0426              BOSS            CP-018
# 245        C-0432              BOSS            CP-018
# 246        C-0474              BOSS            CP-018
# 247        C-0475              BOSS            CP-018
# 248        C-0483              BOSS            CP-018
# 249        C-0486           COUPLET            CP-018
# ...           ...               ...               ...
# 792        C-1958   FLANGE-ONE PIEC            CP-003
# 793        C-1986            FLANGE            CP-003
# 794        C-0038            FLANGE            CP-004
# 795        C-0081            FLANGE            CP-004
# 796        C-0141             PLATE            CP-004
# 797        C-0146            FLANGE            CP-004
# 798        C-0158            FLANGE            CP-004
# 799        C-0166            FLANGE            CP-004
# 800        C-0170            FLANGE            CP-004
# 801        C-0172            FLANGE            CP-004
# 802        C-0191            FLANGE            CP-004
# 803        C-0202            FLANGE            CP-004
# 804        C-0229            FLANGE            CP-004
# 805        C-0231            FLANGE            CP-004
# 806        C-0246            FLANGE            CP-004
# 807        C-0292            FLANGE            CP-004
# 808        C-0295            FLANGE            CP-004
# 809        C-0362            FLANGE            CP-004
# 810        C-0385            FLANGE            CP-004
# 811        C-0398            FLANGE            CP-004
# 812        C-0423            FLANGE            CP-004
# 813        C-0434            FLANGE            CP-004
# 814        C-0468            FLANGE            CP-004
# 815        C-0471            FLANGE            CP-004
# 816        C-0479            FLANGE            CP-004
# 817        C-0480   FLANGE-O SUPPLY            CP-004
# 818        C-0509            FLANGE            CP-004
# 819        C-0510            FLANGE            CP-004
# 820        C-0538            FLANGE            CP-004
# 821        C-0606             PLATE            CP-004
# 822        C-0698   FLANGE-ONE PIEC            CP-004
# 823        C-0732            FLANGE            CP-004
# 824        C-0739            FLANGE            CP-004
# 825        C-0750            FLANGE            CP-004
# 826        C-0778            FLANGE            CP-004
# 827        C-0787            FLANGE            CP-004
# 828        C-0819            FLANGE            CP-004
# 829        C-0836            FLANGE            CP-004
# 830        C-0846            FLANGE            CP-004
# 831        C-0850            FLANGE            CP-004
# 832        C-0875            FLANGE            CP-004
# 833        C-0894            FLANGE            CP-004
# 834        C-0966            FLANGE            CP-004
# 835        C-0977            FLANGE            CP-004
# 836        C-1014   FLANGE-ONE PIEC            CP-004
# 837        C-1066            FLANGE            CP-004
# 838        C-1071            FLANGE            CP-004
# 839        C-1234            FLANGE            CP-004
# 840        C-1314            FLANGE            CP-004
# 841        C-1351            FLANGE            CP-004
# 842        C-1352            FLANGE            CP-004
# 843        C-1354            FLANGE            CP-004
# 844        C-1365     ADAPTER-DRAIN            CP-004
# 845        C-1368            FLANGE            CP-004
# 846        C-1370            FLANGE            CP-004
# 847        C-1373            FLANGE            CP-004
# 848        C-1376            FLANGE            CP-004
# 849        C-1392   FLANGE-ONE PIEC            CP-004
# 850        C-1415            FLANGE            CP-004
# 851        C-1418   FLANGE-ONE PIEC            CP-004
# 852        C-1492            FLANGE            CP-004
# 853        C-1513            FLANGE            CP-004
# 854        C-1518            FLANGE            CP-004
# 855        C-1543            FLANGE            CP-004
# 856        C-1549            FLANGE            CP-004
# 857        C-1555            FLANGE            CP-004
# 858        C-1670            FLANGE            CP-004
# 859        C-1673        FLANGE-SPL            CP-004
# 860        C-1678            FLANGE            CP-004
# 861        C-1680            FLANGE            CP-004
# 862        C-1719            FLANGE            CP-004
# 863        C-1734            FLANGE            CP-004
# 864        C-1736            FLANGE            CP-004
# 865        C-1739            FLANGE            CP-004
# 866        C-1740            FLANGE            CP-004
# 867        C-1749            FLANGE            CP-004
# 868        C-1750            FLANGE            CP-004
# 869        C-1834            FLANGE            CP-004
# 870        C-1849            FLANGE            CP-004
# 871        C-1854            FLANGE            CP-004
# 872        C-1855            FLANGE            CP-004
# 873        C-1943            FLANGE            CP-004
# 874        C-1953            FLANGE            CP-004
# 875        C-1956            FLANGE            CP-004
# 876        C-1983            FLANGE            CP-004
# 877        C-1996   FLANGE-TWO BOLT            CP-004
# 878        C-2043            FLANGE            CP-004
# 879        C-0046   FLANGE-ONE PIEC            CP-005
# 880        C-1804   FLANGE-ONE PIEC            CP-005
# 881        C-0083  FLANGE-ONE PIECE            CP-019
# 882        C-0084            FLANGE            CP-019
# 883        C-0243            FLANGE            CP-019
# 884        C-0257            FLANGE            CP-019
# 885        C-0269            FLANGE            CP-019
# 886        C-0307    CONNECTOR-SEAL            CP-019
# 887        C-0387            FLANGE            CP-019
# 888        C-0513             BLOCK            CP-019
# 889        C-0555            FLANGE            CP-019
# 890        C-0641            FLANGE            CP-019
# 891        C-0643            FLANGE            CP-019
# 892        C-0793            FLANGE            CP-019
# 893        C-0804            FLANGE            CP-019
# 894        C-0869            FLANGE            CP-019
# 895        C-1065              BOSS            CP-019
# 896        C-1496     FLANGE-SADDLE            CP-019
# 897        C-1919             BLOCK            CP-019
# 898        C-0095               NUT            CP-025
# 899        C-0097        NUT-SWIVEL            CP-025
# 900        C-0102        NUT-SWIVEL            CP-025
# 901        C-0134        NUT-SWIVEL            CP-025
# 902        C-0261          NUT-ORFS            CP-025
# 903        C-0337          NUT-ORFS            CP-025
# 904        C-0390        NUT-SWIVEL            CP-025
# 905        C-0579          NUT-ORFS            CP-025
# 906        C-0580          NUT-ORFS            CP-025
# 907        C-1059          NUT-ORFS            CP-025
# 908        C-1620        NUT-SWIVEL            CP-025
# 909        C-1621        NUT-SWIVEL            CP-025
# 910        C-1622        NUT-SWIVEL            CP-025
# 911        C-1623        NUT-SWIVEL            CP-025
# 912        C-1624        NUT-SWIVEL            CP-025
# 913        C-1625        NUT-SWIVEL            CP-025
# 914        C-1626        NUT-SWIVEL            CP-025
# 915        C-1760          NUT-ORFS            CP-025
# 916        C-1867        NUT-SWIVEL            CP-025
# 917        C-2025        NUT-SWIVEL            CP-025
# 918        C-2026        NUT-SWIVEL            CP-025
# 919        C-2027        NUT-SWIVEL            CP-025
# 920        C-2028        NUT-SWIVEL            CP-025
# 921        C-2029        NUT-SWIVEL            CP-025
# 922        C-2030        NUT-SWIVEL            CP-025
# 923        C-0122      HEAD-FLANGED            CP-006
# 924        C-0132      HEAD-FLANGED            CP-006
# 925        C-0142            FLANGE            CP-006
# 926        C-0237      HEAD FLANGED            CP-006
# 927        C-0332      HEAD-FLANGED            CP-006
# 928        C-0333      HEAD-FLANGED            CP-006
# 929        C-0334      HEAD-FLANGED            CP-006
# 930        C-0335      HEAD-FLANGED            CP-006
# 931        C-0370      HEAD-FLANGED            CP-006
# 932        C-0392       HEAD-FLANGE            CP-006
# 933        C-0485      HEAD-FLANGED            CP-006
# 934        C-0492       HEAD-O-RING            CP-006
# 935        C-0498              HEAD            CP-006
# 936        C-0500            FLANGE            CP-006
# 937        C-0532            FLANGE            CP-006
# 938        C-0543            FLANGE            CP-006
# 939        C-0573    HEAD-FLAT FACE            CP-006
# 940        C-0591      HEAD-FLANGED            CP-006
# 941        C-0622      HEAD-FLANGED            CP-006
# 942        C-0628       HEAD O-RING            CP-006
# 943        C-0653       HEAD-O-RING            CP-006
# 944        C-0703      HEAD-FLANGED            CP-006
# 945        C-0709  HEAD-O-RING SEAL            CP-006
# 946        C-0741      HEAD-FLANGED            CP-006
# 947        C-0747       HEAD-FLANGE            CP-006
# 948        C-0748       HEAD-FLANGE            CP-006
# 949        C-0917       FLANGE-HEAD            CP-006
# 950        C-0973       FLANGE-HEAD            CP-006
# 951        C-1113      HEAD-FLANGED            CP-006
# 952        C-1145      HEAD-FLANGED            CP-006
# 953        C-1242      HEAD-FLANGED            CP-006
# 954        C-1342      HEAD-FLANGED            CP-006
# 955        C-1343      HEAD-FLANGED            CP-006
# 956        C-1344      HEAD-FLANGED            CP-006
# 957        C-1346      HEAD-FLANGED            CP-006
# 958        C-1347      HEAD-FLANGED            CP-006
# 959        C-1394         HEAD-SEAL            CP-006
# 960        C-1493      HEAD-FLANGED            CP-006
# 961        C-1545      HEAD-FLANGED            CP-006
# 962        C-1551            COLLAR            CP-006
# 963        C-1553      HEAD-FLANGED            CP-006
# 964        C-1711      HEAD-FLANGED            CP-006
# 965        C-1712      HEAD-FLANGED            CP-006
# 966        C-1897   FLANGE-ONE PIEC            CP-006
# 967        C-2044     ADAPTER-INLET            CP-006
# 968        C-0159         CONNECTOR            CP-016
# 969        C-0223   TEE-ORFS TO BRA            CP-016
# 970        C-0339   TEE-ORFS TO WEL            CP-016
# 971        C-0369               TEE            CP-016
# 972        C-0371           FITTING            CP-016
# 973        C-0399               TEE            CP-016
# 974        C-0487         TEE-BRAZE            CP-016
# 975        C-0488         TEE-BRAZE            CP-016
# 976        C-0600      TEE-BULKHEAD            CP-016
# 977        C-0607               TEE            CP-016
# 978        C-0768               TEE            CP-016
# 979        C-0805      TEE-BULKHEAD            CP-016
# 980        C-0806               TEE            CP-016
# 981        C-0807               TEE            CP-016
# 982        C-0971          TEE-ORFS            CP-016
# 983        C-1836        TEE-FLARED            CP-016
# 984        C-1837        TEE-FLARED            CP-016
# 985        C-1912               TEE            CP-016
# 986        C-0161             BLOCK            CP-020
# 987        C-0770             BLOCK            CP-020
# 988        C-0780             BLOCK            CP-020
# 989        C-0796             BLOCK            CP-020
# 990        C-0899             BLOCK            CP-020
# 991        C-1308              BOSS            CP-020
# 992        C-0320              PLUG            CP-012
# 993        C-1585              PLUG            CP-012
# 994        C-1586              PLUG            CP-012
# 995        C-1587              PLUG            CP-012
# 996        C-1588              PLUG            CP-012
# 997        C-1589              PLUG            CP-012
# 998        C-1872              PLUG            CP-012
# 999        C-0454    FLANGE-CAPTIVE            CP-022
# 1000       C-0455    FLANGE-CAPTIVE            CP-022
# 1001       C-0494            FLANGE            CP-022
# 1002       C-0496            FLANGE            CP-022
# 1003       C-0572      FLANGE-LOOSE            CP-022
# 1004       C-1096            FLANGE            CP-022
# 1005       C-1102            FLANGE            CP-022
# 1006       C-1452    FLANGE-CAPTIVE            CP-022
# 1007       C-1453    FLANGE-CAPTIVE            CP-022
# 1008       C-1584    FLANGE-CAPTIVE            CP-022
# 1009       C-0456      HEAD-FLANGED            CP-007
# 1010       C-0457      HEAD-FLANGED            CP-007
# 1011       C-0458       HEAD-FLANGE            CP-007
# 1012       C-0459      HEAD-FLANGED            CP-007
# 1013       C-0460      HEAD-FLANGED            CP-007
# 1014       C-0461      HEAD-FLANGED            CP-007
# 1015       C-0462      HEAD-FLANGED            CP-007
# 1016       C-0463      HEAD-FLANGED            CP-007
# 1017       C-0621       HEAD-FLANGE            CP-007
# 1018       C-0829      HEAD-FLANGED            CP-007
# 1019       C-1207      HEAD-FLANGED            CP-007
# 1020       C-1449       HEAD-FLANGE            CP-007
# 1021       C-1451       HEAD-FLANGE            CP-007
# 1022       C-1482      HEAD-FLANGED            CP-007
# 1023       C-1494      HEAD-FLANGED            CP-007
# 1024       C-1495      HEAD-FLANGED            CP-007
# 1025       C-1544      HEAD-FLANGED            CP-007
# 1026       C-1713              RING            CP-007
# 1027       C-1717      HEAD-FLANGED            CP-007
# 1028       C-1720      HEAD-FLANGED            CP-007
# 1029       C-1721      HEAD-FLANGED            CP-007
# 1030       C-1894      HEAD-FLANGED            CP-007
# 1031       C-1900      HEAD-FLANGED            CP-007
# 1032       C-1999      HEAD-FLANGED            CP-007
# 1033       C-2034      HEAD-FLANGED            CP-007
# 1034       C-0605          TEE-ORFS            CP-017
# 1035       C-0872      NIPPLE-BRAZE            CP-023
# 1036       C-0873      NIPPLE-BRAZE            CP-023
# 1037       C-0874      NIPPLE-BRAZE            CP-023
# 1038       C-1039       STEM-BRAZED            CP-023
# 1039       C-1041       STEM-BRAZED            CP-023
# 1040       C-1043       STEM-BRAZED            CP-023
# 1041       C-1868     ADAPTER-ELBOW            CP-029
#
#                                    name_y
# 0                                 Sleeves
# 1                                 Sleeves
# 2                                 Sleeves
# 3                                 Sleeves
# 4                                 Sleeves
# 5                                 Sleeves
# 6                                 Sleeves
# 7                                 Sleeves
# 8                                 Sleeves
# 9                                 Sleeves
# 10                                Sleeves
# 11                                Sleeves
# 12                                Sleeves
# 13                                Sleeves
# 14                                Sleeves
# 15                                Sleeves
# 16                                Sleeves
# 17                                Sleeves
# 18                                Sleeves
# 19                                Sleeves
# 20                                Sleeves
# 21                                Sleeves
# 22                                Sleeves
# 23                                Sleeves
# 24                                Sleeves
# 25                                Sleeves
# 26                                Sleeves
# 27                                Sleeves
# 28                                Sleeves
# 29                                Sleeves
# 30                                Sleeves
# 31                                Sleeves
# 32                                Sleeves
# 33                                Sleeves
# 34                                Sleeves
# 35                                Sleeves
# 36                                Sleeves
# 37                                Sleeves
# 38                                Sleeves
# 39                                Sleeves
# 40                                Sleeves
# 41                                Sleeves
# 42                                Sleeves
# 43                                Sleeves
# 44                                Sleeves
# 45                                Sleeves
# 46                                Sleeves
# 47                                Sleeves
# 48                                Sleeves
# 49                                Sleeves
# 50                        JIC 37 - 45 Nut
# 51                        JIC 37 - 45 Nut
# 52                        JIC 37 - 45 Nut
# 53                        JIC 37 - 45 Nut
# 54                        JIC 37 - 45 Nut
# 55                        JIC 37 - 45 Nut
# 56                        JIC 37 - 45 Nut
# 57                        JIC 37 - 45 Nut
# 58                        JIC 37 - 45 Nut
# 59                        JIC 37 - 45 Nut
# 60                        JIC 37 - 45 Nut
# 61                        JIC 37 - 45 Nut
# 62                        JIC 37 - 45 Nut
# 63                        JIC 37 - 45 Nut
# 64                        JIC 37 - 45 Nut
# 65                        JIC 37 - 45 Nut
# 66                        JIC 37 - 45 Nut
# 67                       Straight Adapter
# 68                       Straight Adapter
# 69                       Straight Adapter
# 70                       Straight Adapter
# 71                       Straight Adapter
# 72                       Straight Adapter
# 73                       Straight Adapter
# 74                       Straight Adapter
# 75                       Straight Adapter
# 76                       Straight Adapter
# 77                       Straight Adapter
# 78                       Straight Adapter
# 79                       Straight Adapter
# 80                       Straight Adapter
# 81                       Straight Adapter
# 82                       Straight Adapter
# 83                       Straight Adapter
# 84                       Straight Adapter
# 85                       Straight Adapter
# 86                       Straight Adapter
# 87                       Straight Adapter
# 88                       Straight Adapter
# 89                       Straight Adapter
# 90                       Straight Adapter
# 91                      Threaded Straight
# 92                      Threaded Straight
# 93                      Threaded Straight
# 94                      Threaded Straight
# 95                      Threaded Straight
# 96                      Threaded Straight
# 97                      Threaded Straight
# 98                      Threaded Straight
# 99                      Threaded Straight
# 100                     Threaded Straight
# 101                     Threaded Straight
# 102                     Threaded Straight
# 103                     Threaded Straight
# 104                     Threaded Straight
# 105                     Threaded Straight
# 106                     Threaded Straight
# 107                     Threaded Straight
# 108                     Threaded Straight
# 109                     Threaded Straight
# 110                     Threaded Straight
# 111                     Threaded Straight
# 112                     Threaded Straight
# 113                     Threaded Straight
# 114                     Threaded Straight
# 115                     Threaded Straight
# 116                     Threaded Straight
# 117                     Threaded Straight
# 118                     Threaded Straight
# 119                     Threaded Straight
# 120                     Threaded Straight
# 121                     Threaded Straight
# 122                     Threaded Straight
# 123                     Threaded Straight
# 124                     Threaded Straight
# 125                     Threaded Straight
# 126                     Threaded Straight
# 127                     Threaded Straight
# 128                     Threaded Straight
# 129                     Threaded Straight
# 130                     Threaded Straight
# 131                     Threaded Straight
# 132                     Threaded Straight
# 133                     Threaded Straight
# 134                     Threaded Straight
# 135                     Threaded Straight
# 136                     Threaded Straight
# 137                     Threaded Straight
# 138                     Threaded Straight
# 139                     Threaded Straight
# 140                     Threaded Straight
# 141                     Threaded Straight
# 142                     Threaded Straight
# 143                     Threaded Straight
# 144                     Threaded Straight
# 145                     Threaded Straight
# 146                     Threaded Straight
# 147                     Threaded Straight
# 148                     Threaded Straight
# 149                     Threaded Straight
# 150                     Threaded Straight
# 151                     Threaded Straight
# 152                     Threaded Straight
# 153                     Threaded Straight
# 154                     Threaded Straight
# 155                     Threaded Straight
# 156                     Threaded Straight
# 157                     Threaded Straight
# 158                     Threaded Straight
# 159                     Threaded Straight
# 160                     Threaded Straight
# 161                     Threaded Straight
# 162                     Threaded Straight
# 163                     Threaded Straight
# 164                     Threaded Straight
# 165                     Threaded Straight
# 166                     Threaded Straight
# 167                     Threaded Straight
# 168                     Threaded Straight
# 169                     Threaded Straight
# 170                     Threaded Straight
# 171                     Threaded Straight
# 172                     Threaded Straight
# 173                     Threaded Straight
# 174                     Threaded Straight
# 175                     Threaded Straight
# 176                     Threaded Straight
# 177                     Threaded Straight
# 178                     Threaded Straight
# 179                     Threaded Straight
# 180                     Threaded Straight
# 181                     Threaded Straight
# 182                     Threaded Straight
# 183                     Threaded Straight
# 184                     Threaded Straight
# 185                     Threaded Straight
# 186                     Threaded Straight
# 187                     Threaded Straight
# 188                     Threaded Straight
# 189                     Threaded Straight
# 190                     Threaded Straight
# 191                     Threaded Straight
# 192                     Threaded Straight
# 193                     Threaded Straight
# 194                     Threaded Straight
# 195                     Threaded Straight
# 196                     Threaded Straight
# 197                     Threaded Straight
# 198                     Threaded Straight
# 199                     Threaded Straight
# 200                     Threaded Straight
# 201                     Threaded Straight
# 202                     Threaded Straight
# 203                     Threaded Straight
# 204                     Threaded Straight
# 205                     Threaded Straight
# 206                     Threaded Straight
# 207                     Threaded Straight
# 208                     Threaded Straight
# 209                     Threaded Straight
# 210                     Threaded Straight
# 211                     Threaded Straight
# 212                         Threaded Boss
# 213                         Threaded Boss
# 214                         Threaded Boss
# 215                         Threaded Boss
# 216                         Threaded Boss
# 217                         Threaded Boss
# 218                         Threaded Boss
# 219                         Threaded Boss
# 220                         Threaded Boss
# 221                         Threaded Boss
# 222                         Threaded Boss
# 223                         Threaded Boss
# 224                         Threaded Boss
# 225                         Threaded Boss
# 226                         Threaded Boss
# 227                         Threaded Boss
# 228                         Threaded Boss
# 229                         Threaded Boss
# 230                         Threaded Boss
# 231                         Threaded Boss
# 232                         Threaded Boss
# 233                         Threaded Boss
# 234                         Threaded Boss
# 235                         Threaded Boss
# 236                         Threaded Boss
# 237                         Threaded Boss
# 238                         Threaded Boss
# 239                         Threaded Boss
# 240                         Threaded Boss
# 241                         Threaded Boss
# 242                         Threaded Boss
# 243                         Threaded Boss
# 244                         Threaded Boss
# 245                         Threaded Boss
# 246                         Threaded Boss
# 247                         Threaded Boss
# 248                         Threaded Boss
# 249                         Threaded Boss
# ...                                   ...
# 792            4-bolt Braze/Weld Straight
# 793            4-bolt Braze/Weld Straight
# 794            2-bolt Braze/Weld Straight
# 795            2-bolt Braze/Weld Straight
# 796            2-bolt Braze/Weld Straight
# 797            2-bolt Braze/Weld Straight
# 798            2-bolt Braze/Weld Straight
# 799            2-bolt Braze/Weld Straight
# 800            2-bolt Braze/Weld Straight
# 801            2-bolt Braze/Weld Straight
# 802            2-bolt Braze/Weld Straight
# 803            2-bolt Braze/Weld Straight
# 804            2-bolt Braze/Weld Straight
# 805            2-bolt Braze/Weld Straight
# 806            2-bolt Braze/Weld Straight
# 807            2-bolt Braze/Weld Straight
# 808            2-bolt Braze/Weld Straight
# 809            2-bolt Braze/Weld Straight
# 810            2-bolt Braze/Weld Straight
# 811            2-bolt Braze/Weld Straight
# 812            2-bolt Braze/Weld Straight
# 813            2-bolt Braze/Weld Straight
# 814            2-bolt Braze/Weld Straight
# 815            2-bolt Braze/Weld Straight
# 816            2-bolt Braze/Weld Straight
# 817            2-bolt Braze/Weld Straight
# 818            2-bolt Braze/Weld Straight
# 819            2-bolt Braze/Weld Straight
# 820            2-bolt Braze/Weld Straight
# 821            2-bolt Braze/Weld Straight
# 822            2-bolt Braze/Weld Straight
# 823            2-bolt Braze/Weld Straight
# 824            2-bolt Braze/Weld Straight
# 825            2-bolt Braze/Weld Straight
# 826            2-bolt Braze/Weld Straight
# 827            2-bolt Braze/Weld Straight
# 828            2-bolt Braze/Weld Straight
# 829            2-bolt Braze/Weld Straight
# 830            2-bolt Braze/Weld Straight
# 831            2-bolt Braze/Weld Straight
# 832            2-bolt Braze/Weld Straight
# 833            2-bolt Braze/Weld Straight
# 834            2-bolt Braze/Weld Straight
# 835            2-bolt Braze/Weld Straight
# 836            2-bolt Braze/Weld Straight
# 837            2-bolt Braze/Weld Straight
# 838            2-bolt Braze/Weld Straight
# 839            2-bolt Braze/Weld Straight
# 840            2-bolt Braze/Weld Straight
# 841            2-bolt Braze/Weld Straight
# 842            2-bolt Braze/Weld Straight
# 843            2-bolt Braze/Weld Straight
# 844            2-bolt Braze/Weld Straight
# 845            2-bolt Braze/Weld Straight
# 846            2-bolt Braze/Weld Straight
# 847            2-bolt Braze/Weld Straight
# 848            2-bolt Braze/Weld Straight
# 849            2-bolt Braze/Weld Straight
# 850            2-bolt Braze/Weld Straight
# 851            2-bolt Braze/Weld Straight
# 852            2-bolt Braze/Weld Straight
# 853            2-bolt Braze/Weld Straight
# 854            2-bolt Braze/Weld Straight
# 855            2-bolt Braze/Weld Straight
# 856            2-bolt Braze/Weld Straight
# 857            2-bolt Braze/Weld Straight
# 858            2-bolt Braze/Weld Straight
# 859            2-bolt Braze/Weld Straight
# 860            2-bolt Braze/Weld Straight
# 861            2-bolt Braze/Weld Straight
# 862            2-bolt Braze/Weld Straight
# 863            2-bolt Braze/Weld Straight
# 864            2-bolt Braze/Weld Straight
# 865            2-bolt Braze/Weld Straight
# 866            2-bolt Braze/Weld Straight
# 867            2-bolt Braze/Weld Straight
# 868            2-bolt Braze/Weld Straight
# 869            2-bolt Braze/Weld Straight
# 870            2-bolt Braze/Weld Straight
# 871            2-bolt Braze/Weld Straight
# 872            2-bolt Braze/Weld Straight
# 873            2-bolt Braze/Weld Straight
# 874            2-bolt Braze/Weld Straight
# 875            2-bolt Braze/Weld Straight
# 876            2-bolt Braze/Weld Straight
# 877            2-bolt Braze/Weld Straight
# 878            2-bolt Braze/Weld Straight
# 879                    2-bolt MJ Straight
# 880                    2-bolt MJ Straight
# 881                           4-bolt Boss
# 882                           4-bolt Boss
# 883                           4-bolt Boss
# 884                           4-bolt Boss
# 885                           4-bolt Boss
# 886                           4-bolt Boss
# 887                           4-bolt Boss
# 888                           4-bolt Boss
# 889                           4-bolt Boss
# 890                           4-bolt Boss
# 891                           4-bolt Boss
# 892                           4-bolt Boss
# 893                           4-bolt Boss
# 894                           4-bolt Boss
# 895                           4-bolt Boss
# 896                           4-bolt Boss
# 897                           4-bolt Boss
# 898                              ORFS Nut
# 899                              ORFS Nut
# 900                              ORFS Nut
# 901                              ORFS Nut
# 902                              ORFS Nut
# 903                              ORFS Nut
# 904                              ORFS Nut
# 905                              ORFS Nut
# 906                              ORFS Nut
# 907                              ORFS Nut
# 908                              ORFS Nut
# 909                              ORFS Nut
# 910                              ORFS Nut
# 911                              ORFS Nut
# 912                              ORFS Nut
# 913                              ORFS Nut
# 914                              ORFS Nut
# 915                              ORFS Nut
# 916                              ORFS Nut
# 917                              ORFS Nut
# 918                              ORFS Nut
# 919                              ORFS Nut
# 920                              ORFS Nut
# 921                              ORFS Nut
# 922                              ORFS Nut
# 923                Braze/Weld Flange Head
# 924                Braze/Weld Flange Head
# 925                Braze/Weld Flange Head
# 926                Braze/Weld Flange Head
# 927                Braze/Weld Flange Head
# 928                Braze/Weld Flange Head
# 929                Braze/Weld Flange Head
# 930                Braze/Weld Flange Head
# 931                Braze/Weld Flange Head
# 932                Braze/Weld Flange Head
# 933                Braze/Weld Flange Head
# 934                Braze/Weld Flange Head
# 935                Braze/Weld Flange Head
# 936                Braze/Weld Flange Head
# 937                Braze/Weld Flange Head
# 938                Braze/Weld Flange Head
# 939                Braze/Weld Flange Head
# 940                Braze/Weld Flange Head
# 941                Braze/Weld Flange Head
# 942                Braze/Weld Flange Head
# 943                Braze/Weld Flange Head
# 944                Braze/Weld Flange Head
# 945                Braze/Weld Flange Head
# 946                Braze/Weld Flange Head
# 947                Braze/Weld Flange Head
# 948                Braze/Weld Flange Head
# 949                Braze/Weld Flange Head
# 950                Braze/Weld Flange Head
# 951                Braze/Weld Flange Head
# 952                Braze/Weld Flange Head
# 953                Braze/Weld Flange Head
# 954                Braze/Weld Flange Head
# 955                Braze/Weld Flange Head
# 956                Braze/Weld Flange Head
# 957                Braze/Weld Flange Head
# 958                Braze/Weld Flange Head
# 959                Braze/Weld Flange Head
# 960                Braze/Weld Flange Head
# 961                Braze/Weld Flange Head
# 962                Braze/Weld Flange Head
# 963                Braze/Weld Flange Head
# 964                Braze/Weld Flange Head
# 965                Braze/Weld Flange Head
# 966                Braze/Weld Flange Head
# 967                Braze/Weld Flange Head
# 968                          Threaded Tee
# 969                          Threaded Tee
# 970                          Threaded Tee
# 971                          Threaded Tee
# 972                          Threaded Tee
# 973                          Threaded Tee
# 974                          Threaded Tee
# 975                          Threaded Tee
# 976                          Threaded Tee
# 977                          Threaded Tee
# 978                          Threaded Tee
# 979                          Threaded Tee
# 980                          Threaded Tee
# 981                          Threaded Tee
# 982                          Threaded Tee
# 983                          Threaded Tee
# 984                          Threaded Tee
# 985                          Threaded Tee
# 986                           2-bolt Boss
# 987                           2-bolt Boss
# 988                           2-bolt Boss
# 989                           2-bolt Boss
# 990                           2-bolt Boss
# 991                           2-bolt Boss
# 992                               MJ Plug
# 993                               MJ Plug
# 994                               MJ Plug
# 995                               MJ Plug
# 996                               MJ Plug
# 997                               MJ Plug
# 998                               MJ Plug
# 999   Free-Floating 4-bolt Captive Flange
# 1000  Free-Floating 4-bolt Captive Flange
# 1001  Free-Floating 4-bolt Captive Flange
# 1002  Free-Floating 4-bolt Captive Flange
# 1003  Free-Floating 4-bolt Captive Flange
# 1004  Free-Floating 4-bolt Captive Flange
# 1005  Free-Floating 4-bolt Captive Flange
# 1006  Free-Floating 4-bolt Captive Flange
# 1007  Free-Floating 4-bolt Captive Flange
# 1008  Free-Floating 4-bolt Captive Flange
# 1009                       MJ Flange Head
# 1010                       MJ Flange Head
# 1011                       MJ Flange Head
# 1012                       MJ Flange Head
# 1013                       MJ Flange Head
# 1014                       MJ Flange Head
# 1015                       MJ Flange Head
# 1016                       MJ Flange Head
# 1017                       MJ Flange Head
# 1018                       MJ Flange Head
# 1019                       MJ Flange Head
# 1020                       MJ Flange Head
# 1021                       MJ Flange Head
# 1022                       MJ Flange Head
# 1023                       MJ Flange Head
# 1024                       MJ Flange Head
# 1025                       MJ Flange Head
# 1026                       MJ Flange Head
# 1027                       MJ Flange Head
# 1028                       MJ Flange Head
# 1029                       MJ Flange Head
# 1030                       MJ Flange Head
# 1031                       MJ Flange Head
# 1032                       MJ Flange Head
# 1033                       MJ Flange Head
# 1034               Threaded Lateral Cross
# 1035                     Stems and Shells
# 1036                     Stems and Shells
# 1037                     Stems and Shells
# 1038                     Stems and Shells
# 1039                     Stems and Shells
# 1040                     Stems and Shells
# 1041                        Elbow Adapter
#
# [1042 rows x 4 columns]

# %%
#merging all components data into a final components dataframe
adapt_merge= pd.merge(components, adaptors, how= 'outer', on='component_id')
boss_merge= pd.merge(adapt_merge, boss, how= 'outer', on= 'component_id')
elbow_merge= pd.merge(boss_merge, elbow, how= 'outer', on= 'component_id')
float_merge= pd.merge(elbow_merge, comp_float, how= 'outer', on= 'component_id')
hfl_merge= pd.merge(float_merge, hfl, how= 'outer', on= 'component_id')
nut_merge= pd.merge(hfl_merge, nut, how= 'outer', on= 'component_id')
other_merge= pd.merge(nut_merge, other, how= 'outer', on= 'component_id')
sleeve_merge= pd.merge(other_merge, sleeve, how= 'outer', on= 'component_id')
straight_merge= pd.merge(sleeve_merge, straight, how= 'outer', on= 'component_id')
tee_merge= pd.merge(straight_merge, tee, how= 'outer', on= 'component_id')
final_merge= pd.merge(tee_merge, threaded, how= 'outer', on= 'component_id')

# %%
components.shape, final_merge.shape

# %%
test_set= test_data.copy()
train_set= train_data.copy()

# %%
#getting rid of duplicate columns
components_data = final_merge.loc[:,~final_merge.columns.duplicated()]

# %%
components_data.shape

# %%
# columns= ['tube_assembly_id', 'material_id', 'diameter', 'wall', 'length', 'bend_radius']
tube_merge= tube_data.copy()

# %%
train_set.shape,test_set.shape,  tube_merge.shape

# %%
train_set= pd.merge(train_set, tube_merge)
test_set= pd.merge(test_set, tube_merge)

# %%
train_set.shape, test_set.shape, bill_data.shape

# %%
train_set= pd.merge(train_set, bill_data)
test_set= pd.merge(test_set, bill_data)

# %%
train_set.shape, test_set.shape

# %%
train_component_1= train_set['component_id_1'].unique()
train_component_2= train_set['component_id_2'].unique()
train_component_3= train_set['component_id_3'].unique()
train_component_4= train_set['component_id_4'].unique()
train_component_5= train_set['component_id_5'].unique()
train_component_6= train_set['component_id_6'].unique()
train_component_7= train_set['component_id_7'].unique()
train_component_8= train_set['component_id_8'].unique()

# %%
test_component_1= test_set['component_id_1'].unique()
test_component_2= test_set['component_id_2'].unique()
test_component_3= test_set['component_id_3'].unique()
test_component_4= test_set['component_id_4'].unique()
test_component_5= test_set['component_id_5'].unique()
test_component_6= test_set['component_id_6'].unique()
test_component_7= test_set['component_id_7'].unique()
test_component_8= test_set['component_id_8'].unique()

# %%
train_comp_one_data= components_data[components_data['component_id'].isin(train_component_1)]
train_comp_one_data= train_comp_one_data.rename(columns= {'component_id': 'component_id_1'})
train_comp_two_data= components_data[components_data['component_id'].isin(train_component_2)]
train_comp_two_data= train_comp_two_data.rename(columns={'component_id': 'component_id_2'})
train_comp_three_data= components_data[components_data['component_id'].isin(train_component_3)]
train_comp_three_data= train_comp_three_data.rename(columns={'component_id': 'component_id_3'})
train_comp_four_data= components_data[components_data['component_id'].isin(train_component_4)]
train_comp_four_data= train_comp_four_data.rename(columns={'component_id': 'component_id_4'})
train_comp_five_data= components_data[components_data['component_id'].isin(train_component_5)]
train_comp_five_data= train_comp_five_data.rename(columns={'component_id': 'component_id_5'})
train_comp_six_data= components_data[components_data['component_id'].isin(train_component_6)]
train_comp_six_data= train_comp_six_data.rename(columns={'component_id': 'component_id_6'})
train_comp_seven_data= components_data[components_data['component_id'].isin(train_component_7)]
train_comp_seven_data= train_comp_seven_data.rename(columns={'component_id': 'component_id_7'})
train_comp_eight_data= components_data[components_data['component_id'].isin(train_component_8)]
train_comp_eight_data= train_comp_eight_data.rename(columns={'component_id': 'component_id_8'})

# %%
test_comp_one_data= components_data[components_data['component_id'].isin(test_component_1)]
test_comp_one_data= test_comp_one_data.rename(columns= {'component_id': 'component_id_1'})
test_comp_two_data= components_data[components_data['component_id'].isin(test_component_2)]
test_comp_two_data= test_comp_two_data.rename(columns={'component_id': 'component_id_2'})
test_comp_three_data= components_data[components_data['component_id'].isin(test_component_3)]
test_comp_three_data= test_comp_three_data.rename(columns={'component_id': 'component_id_3'})
test_comp_four_data= components_data[components_data['component_id'].isin(test_component_4)]
test_comp_four_data= test_comp_four_data.rename(columns={'component_id': 'component_id_4'})
test_comp_five_data= components_data[components_data['component_id'].isin(test_component_5)]
test_comp_five_data= test_comp_five_data.rename(columns={'component_id': 'component_id_5'})
test_comp_six_data= components_data[components_data['component_id'].isin(test_component_6)]
test_comp_six_data= test_comp_six_data.rename(columns={'component_id': 'component_id_6'})
test_comp_seven_data= components_data[components_data['component_id'].isin(test_component_7)]
test_comp_seven_data= test_comp_seven_data.rename(columns={'component_id': 'component_id_7'})
test_comp_eight_data= components_data[components_data['component_id'].isin(test_component_8)]
test_comp_eight_data= test_comp_eight_data.rename(columns={'component_id': 'component_id_8'})

# %%
train_set= pd.merge(train_set, train_comp_one_data, how='outer', on='component_id_1')
test_set= pd.merge(test_set, test_comp_one_data, how='outer', on='component_id_1')

# %%
train_set.shape, test_set.shape

# %%
train_set= pd.merge(train_set, train_comp_two_data, how='outer', on='component_id_2')
test_set= pd.merge(test_set, test_comp_two_data, how='outer', on='component_id_2')

# %%
train_set.shape, test_set.shape

# %%
train_set= pd.merge(train_set, train_comp_three_data, how='outer', on='component_id_3')
test_set= pd.merge(test_set, test_comp_three_data, how='outer', on='component_id_3')

# %%
train_set.shape, test_set.shape

# %%
train_set= pd.merge(train_set, train_comp_four_data, how='outer', on='component_id_4')
test_set= pd.merge(test_set, test_comp_four_data, how='outer', on='component_id_4')

# %%
train_set.shape, test_set.shape

# %%
train_set= pd.merge(train_set, train_comp_five_data, how='outer', on='component_id_5')
test_set= pd.merge(test_set, test_comp_five_data, how='outer', on='component_id_5')

# %%
train_set.shape, test_set.shape

# %%
train_set= pd.merge(train_set, train_comp_six_data, how='outer', on='component_id_6')
test_set= pd.merge(test_set, test_comp_six_data, how='outer', on='component_id_6')

# %%
train_set.shape, test_set.shape

# %%
train_set= pd.merge(train_set, train_comp_seven_data, how='outer', on='component_id_7')
test_set= pd.merge(test_set, test_comp_seven_data, how='outer', on='component_id_7')

# %%
train_set.shape, test_set.shape

# %%
train_set= pd.merge(train_set, train_comp_eight_data, how='outer', on='component_id_8')
test_set= pd.merge(test_set, test_comp_eight_data, how='outer', on='component_id_8')

# %%
train_set.shape, test_set.shape

# %%
train_set= train_set.loc[:,~train_set.columns.duplicated()]
test_set= test_set.loc[:,~test_set.columns.duplicated()]

# %%
train_set.shape, test_set.shape

# %%
train_set= train_set.replace([np.inf, -np.inf], np.nan)
test_set= test_set.replace([np.inf, -np.inf], np.nan)

# %%
train_set= train_set.fillna(0)
test_set= test_set.fillna(0)

# %%
#grabbed the unique tube assembly ids for train and test data
train_assembly_unique= train_set['tube_assembly_id'].unique()
test_assembly_unique= test_set['tube_assembly_id']. unique()

# %%
#split the unique assembies into train and validate groups
train_assemblies0, test_assemblies0= train_test_split(train_assembly_unique, train_size= 0.80, test_size=0.2, random_state= 42)

# %%
#looked at shape of both train and val assemblies
train_assemblies0.shape, test_assemblies0.shape

# %%
train_assemblies1, test_assemblies1= train_test_split(train_assemblies0, train_size= 0.80, test_size= 0.2, random_state=42)

# %%
#created train an val datasets by grabbing only data associated with the unique assemblies for that dataset
train0= train_set[train_set['tube_assembly_id'].isin(train_assemblies0)]
val0= train_set[train_set['tube_assembly_id'].isin(test_assemblies0)]

# %%
train1= train_set[train_set['tube_assembly_id'].isin(train_assemblies1)]
val1= train_set[train_set['tube_assembly_id'].isin(test_assemblies1)]

# %%
#checked the shape of train and validate
train0.shape, val0.shape

# %%
#created a wrangle function
def wrangle(df):
    df= df.copy()
    df['quote_date']= pd.to_datetime(df['quote_date'], infer_datetime_format= True)
    df['quote_date_year'] = df['quote_date'].dt.year
    df['quote_date_month'] = df['quote_date'].dt.month
    df= df.drop(columns=['quote_date'])
    return df

# %%
train0= wrangle(train0)
val0= wrangle(val0)
# train1=wrangle(train1)
# val1= wrangle(val1)
test= wrangle(test_set)

# %%
train0.shape, val0.shape, train1.shape, val1.shape, test.shape

# %%
#log target
train0_target= np.log1p(train0['cost'])
# train1_target= np.log1p(train1['cost'])
val0_target= np.log1p(val0['cost'])
# val1_target= np.log1p(val1['cost'])

#drop target and tube id
train0_features= train0.drop(columns=['cost', 'tube_assembly_id'])
val0_features= val0.drop(columns=['cost', 'tube_assembly_id'])
# train1_features= train1.drop(columns=['cost', 'tube_assembly_id'])
# val1_features= val1.drop(columns=['cost', 'tube_assembly_id'])
test_ids= test['id']
test= test.drop(columns=['id','tube_assembly_id'])

# %%
test.shape, sample_sub.shape

# %%
#created a pipeline with an ordinal encoder and randomforestregressor
pipeline= make_pipeline(ce.OrdinalEncoder(),
                       RandomForestRegressor(n_estimators=1000, random_state=42, n_jobs=-1))

# %%
pipeline.fit(train0_features, train0_target)

# %%
#fitted training features and target to pipeline
pipeline.fit(train1_features, train1_target)

# %%
#made predictions on validations features
# y_pred1= pipeline.predict(val1_features)
#extra validation
y_pred0= pipeline.predict(val0_features)

# %%
#root mean squared error with log target for validation and extra validation
# np.sqrt(mean_squared_error(val1_target, y_pred1)), 
np.sqrt(mean_squared_error(val0_target, y_pred0))

# %%
#R squared scores 
# r2_score(val1_target, y_pred1), 
r2_score(val0_target, y_pred0)

# %%
y_pred= pipeline.predict(test)

# %%
y_pred= np.expm1(y_pred)

# %%
sample_sub['cost']= y_pred

# %%
sample_sub.to_csv('sample_submission.csv', index=False)

# %%
encoder= ce.OrdinalEncoder()
# train1_encoded= encoder.fit_transform(train1_features)
# val1_encoded= encoder.transform(val1_features)
train0_encoded= encoder.fit_transform(train0_features)
val0_encoded= encoder.transform(val0_features)
test_encoded= encoder.transform(test)

# %%
# eval_set = [(train1_encoded, train1_target), 
#             (val1_encoded, val1_target)]
model= XGBRegressor(n_estimators= 1000,eval_metric='rmse', early_stopping_rounds=10, random_state=42, n_jobs=-1)

# %%
model.fit(train0_encoded, train0_target)

# %%
# y_pred1= model.predict(val1_encoded)
y_pred0= model.predict(val0_encoded)

# %%
# np.sqrt(mean_squared_error(val1_target, y_pred1)), 
np.sqrt(mean_squared_error(val0_target, y_pred0))

# %%
# r2_score(val1_target, y_pred1), 
r2_score(val0_target, y_pred0)

# %%
columns= ['end_form_id_3_x','connection_type_id_3_x', 'mj_plug_class_code_y_y']
test_encoded[columns]= test_encoded[columns].replace(to_replace= ['A-001', 'B-002', 'MJ-005'], value=0)

# %%
sub_pred= model.predict(test_encoded)

# %%
sub_pred.shape

# %%
sub_pred= np.expm1(sub_pred)

# %%
sample_sub['cost']= sub_pred

# %%
sample_sub.to_csv('sample_submission.csv', index=False)

# %%
sample_sub.head()

# %%
test_set.head()
